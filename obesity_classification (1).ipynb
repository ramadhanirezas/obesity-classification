# %% [markdown]
# # Importing Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import zscore
from scipy.stats import gaussian_kde

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots


import missingno as msno
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set(style="darkgrid",font_scale=1.5)
pd.set_option("display.max.columns",None)
pd.set_option("display.max.rows",None)
# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning)  # Suppress user warnings
warnings.filterwarnings("ignore", category=FutureWarning)  # Suppress future warnings

# %% [markdown]
# # Machine learning library and performance metrices

# %%
from xgboost import XGBClassifier

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import label_binarize
from sklearn.preprocessing import label_binarize
from imblearn.combine import SMOTETomek
from imblearn.combine import SMOTEENN

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/data mining/uas lagi obesity/Obesity prediction.csv')

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history', 'FAVC', 'FCVC',
#        'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS',
#        'Obesity'],
#       dtype='object')

# %%
# Rename columns using a dictionary
new_column_names = {
    'Gender': 'GENDER',
    'Age': 'AGE',
    'Height': 'HEIGHT',
    'Weight': 'WEIGHT',
    'family_history': 'FAMILY_HISTORY',
    'FAVC': 'FAVC',
    'FCVC': 'FCVC',
    'NCP': 'NCP',
    'CAEC': 'CAEC',
    'SMOKE': 'SMOKE',
    'CH2O': 'CH2O',
    'SCC': 'SCC',
    'FAF': 'FAF',
    'TUE': 'TUE',
    'CALC': 'CALC',
    'MTRANS': 'MTRANS',
    'Obesity': 'OBESITY'
    }
df = df.rename(columns=new_column_names)

# %%
df.head()
# Out:
#    GENDER   AGE  HEIGHT  WEIGHT FAMILY_HISTORY FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                OBESITY
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GENDER          2111 non-null   object
#  1   AGE             2111 non-null   float64
#  2   HEIGHT          2111 non-null   float64
#  3   WEIGHT          2111 non-null   float64
#  4   FAMILY_HISTORY  2111 non-null   object
#  5   FAVC            2111 non-null   object
#  6   FCVC            2111 non-null   float64
#  7   NCP             2111 non-null   float64
#  8   CAEC            2111 non-null   object
#  9   SMOKE           2111 non-null   object
#  10  CH2O            2111 non-null   float64
#  11  SCC             2111 non-null   object
#  12  FAF             2111 non-null   float64
#  13  TUE             2111 non-null   float64
#  14  CALC            2111 non-null   object
#  15  MTRANS          2111 non-null   object
#  16  OBESITY         2111 non-null   object
# ...

# %%
df.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing Values"})
# Out:
#                 Total No. of Missing Values
# GENDER                                    0
# AGE                                       0
# HEIGHT                                    0
# WEIGHT                                    0
# FAMILY_HISTORY                            0
# FAVC                                      0
# FCVC                                      0
# NCP                                       0
# CAEC                                      0
# SMOKE                                     0
# CH2O                                      0
# SCC                                       0
# FAF                                       0
# TUE                                       0
# CALC                                      0
# MTRANS                                    0
# OBESITY                                   0

# %%
print("Duplicate Values =",df.duplicated().sum())
# Out:
# Duplicate Values = 24

# %%
df.drop_duplicates(inplace=True)

# %%
print("Duplicate Values =",df.duplicated().sum())
# Out:
# Duplicate Values = 0

# %%
df.shape
# Out:
# (2087, 17)

# %%
numeric_data = df.select_dtypes(include=[np.number])
numeric_data.head()
# Out:
#     AGE  HEIGHT  WEIGHT  FCVC  NCP  CH2O  FAF  TUE
# 0  21.0    1.62    64.0   2.0  3.0   2.0  0.0  1.0
# 1  21.0    1.52    56.0   3.0  3.0   3.0  3.0  0.0
# 2  23.0    1.80    77.0   2.0  3.0   2.0  2.0  1.0
# 3  27.0    1.80    87.0   3.0  3.0   2.0  2.0  0.0
# 4  22.0    1.78    89.8   2.0  1.0   2.0  0.0  0.0

# %%
categorical_data = df.select_dtypes(exclude=[np.number])
categorical_data.head()
# Out:
#    GENDER FAMILY_HISTORY FAVC       CAEC SMOKE  SCC        CALC  \
# 0  Female            yes   no  Sometimes    no   no          no
# 1  Female            yes   no  Sometimes   yes  yes   Sometimes
# 2    Male            yes   no  Sometimes    no   no  Frequently
# 3    Male             no   no  Sometimes    no   no  Frequently
# 4    Male             no   no  Sometimes    no   no   Sometimes
#
#                   MTRANS              OBESITY
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
numeric_data.corr()
# Out:
#              AGE    HEIGHT    WEIGHT      FCVC       NCP      CH2O       FAF  \
# AGE     1.000000 -0.031748  0.198160  0.013572 -0.055823 -0.044058 -0.148202
# HEIGHT -0.031748  1.000000  0.457468 -0.040363  0.227806  0.220487  0.293584
# WEIGHT  0.198160  0.457468  1.000000  0.216574  0.092149  0.203823 -0.056490
# FCVC    0.013572 -0.040363  0.216574  1.000000  0.034885  0.081332  0.022003
# NCP    -0.055823  0.227806  0.092149  0.034885  1.000000  0.075335  0.127816
# CH2O   -0.044058  0.220487  0.203823  0.081332  0.075335  1.000000  0.165310
# FAF    -0.148202  0.293584 -0.056490  0.022003  0.127816  0.165310  1.000000
# TUE    -0.302927  0.041808 -0.079351 -0.104128  0.015693  0.020704  0.058716
#
#              TUE
# AGE    -0.302927
# HEIGHT  0.041808
# WEIGHT -0.079351
# FCVC   -0.104128
# NCP     0.015693
# CH2O    0.020704
# FAF     0.058716
# TUE     1.000000

# %%
# Create the heatmap
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Data visualization

# %%
categorical_columns = df.select_dtypes(include="object").columns.tolist()
for col in categorical_columns:
    print(f"{col} : value and frequency")
    print(df[col].value_counts())
    print("-"*50)
# Out:
# GENDER : value and frequency
# GENDER
# Male      1052
# Female    1035
# Name: count, dtype: int64
# --------------------------------------------------
# FAMILY_HISTORY : value and frequency
# FAMILY_HISTORY
# yes    1722
# no      365
# Name: count, dtype: int64
# --------------------------------------------------
# FAVC : value and frequency
# FAVC
# yes    1844
# no      243
# Name: count, dtype: int64
# --------------------------------------------------
# CAEC : value and frequency
# CAEC
# Sometimes     1761
# Frequently     236
# Always          53
# no              37
# Name: count, dtype: int64
# --------------------------------------------------
# SMOKE : value and frequency
# SMOKE
# no     2043
# yes      44
# Name: count, dtype: int64
# --------------------------------------------------
# SCC : value and frequency
# SCC
# no     1991
# yes      96
# Name: count, dtype: int64
# --------------------------------------------------
# CALC : value and frequency
# CALC
# ...

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.countplot(df, x="GENDER")
plt.title('Gender distribution ')
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.countplot(df, x="FAMILY_HISTORY")
plt.title('Family history distribution ')
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.countplot(df, x="FAVC")
plt.title('FAVC distribution ')
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.countplot(df, x="CAEC")
plt.title('CAEC distribution ')
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.countplot(df, x="SMOKE")
plt.title('Smoke distribution ')
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.countplot(df, x="SCC")
plt.title('SCC distribution ')
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.countplot(df, x="CALC")
plt.title('CALC distribution ')
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.countplot(df, x="MTRANS")
plt.title('MTRANS distribution ')
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.countplot(df, x="OBESITY")
plt.title('OBESITY distribution ')
plt.xticks(rotation=90)  # Rotate x-axis labels
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.histplot(df, x='AGE', kde=True)
plt.title(f"Distribution of AGE")
plt.xlabel("AGE", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.histplot(df, x='WEIGHT', kde=True)
plt.title(f"Distribution of HEIGHT")
plt.xlabel("HEIGHT", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.histplot(df, x='HEIGHT', kde=True)
plt.title(f"Distribution of HEIGHT")
plt.xlabel("HEIGHT", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.histplot(df, x='FCVC', kde=True)
plt.title(f"Distribution of FCVC")
plt.xlabel("FCVC", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.histplot(df, x='NCP', kde=True)
plt.title(f"Distribution of NCP")
plt.xlabel("NCP", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.histplot(df, x='CH2O', kde=True)
plt.title(f"Distribution of CH2O")
plt.xlabel("CH2O", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.histplot(df, x='FAF', kde=True)
plt.title(f"Distribution of FAF")
plt.xlabel("FAF", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.histplot(df, x='TUE', kde=True)
plt.title(f"Distribution of TUE")
plt.xlabel("TUE", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
sns.pairplot(numeric_data, diag_kind="kde", corner=True, height=2.5)
plt.show()

# %% [markdown]
# # Feature engineering and scaling

# %%
# Create BMI
df["BMI"] = df["WEIGHT"] / (df["HEIGHT"] ** 2)
df.head()
# Out:
#    GENDER   AGE  HEIGHT  WEIGHT FAMILY_HISTORY FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                OBESITY        BMI
# 0        Normal_Weight  24.386526
# 1        Normal_Weight  24.238227
# ...

# %%
df = df.drop(["WEIGHT", "HEIGHT"], axis=1)

# %%
df.head()
# Out:
#    GENDER   AGE FAMILY_HISTORY FAVC  FCVC  NCP       CAEC SMOKE  CH2O  SCC  \
# 0  Female  21.0            yes   no   2.0  3.0  Sometimes    no   2.0   no
# 1  Female  21.0            yes   no   3.0  3.0  Sometimes   yes   3.0  yes
# 2    Male  23.0            yes   no   2.0  3.0  Sometimes    no   2.0   no
# 3    Male  27.0             no   no   3.0  3.0  Sometimes    no   2.0   no
# 4    Male  22.0             no   no   2.0  1.0  Sometimes    no   2.0   no
#
#    FAF  TUE        CALC                 MTRANS              OBESITY        BMI
# 0  0.0  1.0          no  Public_Transportation        Normal_Weight  24.386526
# 1  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight  24.238227
# 2  2.0  1.0  Frequently  Public_Transportation        Normal_Weight  23.765432
# 3  2.0  0.0  Frequently                Walking   Overweight_Level_I  26.851852
# 4  0.0  0.0   Sometimes  Public_Transportation  Overweight_Level_II  28.342381

# %%
# Ordinal Encoding
category_column = ["GENDER","FAMILY_HISTORY","FAVC","CAEC","SMOKE","SCC","CALC"]

# %%
oe = OrdinalEncoder()
df[category_column] = oe.fit_transform(df[category_column])
df.head()
# Out:
#    GENDER   AGE  FAMILY_HISTORY  FAVC  FCVC  NCP  CAEC  SMOKE  CH2O  SCC  FAF  \
# 0     0.0  21.0             1.0   0.0   2.0  3.0   2.0    0.0   2.0  0.0  0.0
# 1     0.0  21.0             1.0   0.0   3.0  3.0   2.0    1.0   3.0  1.0  3.0
# 2     1.0  23.0             1.0   0.0   2.0  3.0   2.0    0.0   2.0  0.0  2.0
# 3     1.0  27.0             0.0   0.0   3.0  3.0   2.0    0.0   2.0  0.0  2.0
# 4     1.0  22.0             0.0   0.0   2.0  1.0   2.0    0.0   2.0  0.0  0.0
#
#    TUE  CALC                 MTRANS              OBESITY        BMI
# 0  1.0   3.0  Public_Transportation        Normal_Weight  24.386526
# 1  0.0   2.0  Public_Transportation        Normal_Weight  24.238227
# 2  1.0   1.0  Public_Transportation        Normal_Weight  23.765432
# 3  0.0   1.0                Walking   Overweight_Level_I  26.851852
# 4  0.0   2.0  Public_Transportation  Overweight_Level_II  28.342381

# %%
df = pd.get_dummies(columns=["MTRANS"],data=df,drop_first=True)

# %%
boolean_cols_auto = df.select_dtypes(include=['bool']).columns
df[boolean_cols_auto] = df[boolean_cols_auto].astype(int)

# %%
le = LabelEncoder()
df["OBESITY"] = le.fit_transform(df["OBESITY"])

# %%
df.head()
# Out:
#    GENDER   AGE  FAMILY_HISTORY  FAVC  FCVC  NCP  CAEC  SMOKE  CH2O  SCC  FAF  \
# 0     0.0  21.0             1.0   0.0   2.0  3.0   2.0    0.0   2.0  0.0  0.0
# 1     0.0  21.0             1.0   0.0   3.0  3.0   2.0    1.0   3.0  1.0  3.0
# 2     1.0  23.0             1.0   0.0   2.0  3.0   2.0    0.0   2.0  0.0  2.0
# 3     1.0  27.0             0.0   0.0   3.0  3.0   2.0    0.0   2.0  0.0  2.0
# 4     1.0  22.0             0.0   0.0   2.0  1.0   2.0    0.0   2.0  0.0  0.0
#
#    TUE  CALC  OBESITY        BMI  MTRANS_Bike  MTRANS_Motorbike  \
# 0  1.0   3.0        1  24.386526            0                 0
# 1  0.0   2.0        1  24.238227            0                 0
# 2  1.0   1.0        1  23.765432            0                 0
# 3  0.0   1.0        5  26.851852            0                 0
# 4  0.0   2.0        6  28.342381            0                 0
#
#    MTRANS_Public_Transportation  MTRANS_Walking
# 0                             1               0
# ...

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.histplot(df, x='BMI', kde=True)
plt.title(f"Distribution of BMI")
plt.xlabel("BMI", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
# Calculate the number of rows and columns needed for subplots
num_cols = len(df.columns)
num_rows = (num_cols + 3) // 4  # Calculate rows, ensuring at least one

plt.figure(figsize=(15, 10))
for i, col in enumerate(df.columns):
    plt.subplot(num_rows, 4, i + 1)  # Use calculated rows and columns
    sns.boxplot(y=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Machine learning models for prediction

# %%
x = df.drop(['OBESITY'], axis = 1)
y = df['OBESITY']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42,stratify=y)

# %%
print("x_train - >  ",x_train.shape)
print("y_train - >  ",y_train.shape)
print("x_test  - >  ",x_test.shape)
print("y_test  - >  ",y_test.shape)
# Out:
# x_train - >   (1669, 18)
# y_train - >   (1669,)
# x_test  - >   (418, 18)
# y_test  - >   (418,)

# %%
def evaluate_xgboost(model, x_train, y_train, x_test, y_test):
    """Evaluates the performance of an XGBoost model."""

    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    cm = confusion_matrix(y_test, y_pred)

    print("XGBoost Performance Metrics:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-score: {f1:.4f}")

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    return accuracy, precision, recall, f1


xgb_model = XGBClassifier()
accuracy, precision, recall, f1 = evaluate_xgboost(xgb_model, x_train, y_train, x_test, y_test)
# Out:
# XGBoost Performance Metrics:
# Accuracy: 0.9904
# Precision: 0.9908
# Recall: 0.9904
# F1-score: 0.9904

# %%
import joblib

joblib.dump(xgb_model, 'xgb_model.pkl')
# Out:
# ['xgb_model.pkl']
